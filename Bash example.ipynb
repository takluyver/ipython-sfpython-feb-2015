# %%
echo $HOME
# Out:
# /home/takluyver

# %%
ls -l
# Out:
# total 5136
# -rw-rw-r-- 1 takluyver takluyver     793 Feb 11 16:59 Bash example.ipynb
# -rw-rw-r-- 1 takluyver takluyver   12607 Feb 11 09:54 ipy_kernel_and_terminal.svg
# -rw-rw-r-- 1 takluyver takluyver   53836 Feb 11 12:24 ipy_terminal.png
# -rw-rw-r-- 1 takluyver takluyver 1697141 Feb 11 12:13 mugshots.png
# -rw-rw-r-- 1 takluyver takluyver 3364161 Feb 11 12:12 mugshots.xcf
# -rw-rw-r-- 1 takluyver takluyver   23578 Feb 11 20:09 R example.ipynb
# -rw-rw-r-- 1 takluyver takluyver   30252 Feb 11 20:08 Talk.ipynb
# -rw-rw-r-- 1 takluyver takluyver   21949 Feb 11 15:02 widget_architecture.svg

# %%
display < ipy_terminal.png
